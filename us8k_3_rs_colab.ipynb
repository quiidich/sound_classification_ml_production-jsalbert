# %%
from google.colab import drive
drive.mount('/content/gdrive/')

import shutil
import os

dataset_path = '/content/gdrive/MyDrive/Colab Notebooks'
shutil.copy(os.path.join(dataset_path, 'feature_log-mel_96_rs_df.pickle'), 'feature_log-mel_96_rs_df.pickle')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# 'feature_log-mel_96_rs_df.pickle'

# %%
import numpy as np
import pandas as pd

from datetime import datetime

# %%
# load feature data

import pickle

with open('feature_log-mel_96_rs_df.pickle','rb') as f:
    dataset_df = pickle.load(f)

# %%
# split data

from sklearn.model_selection import train_test_split

# Split the dataset
X = np.array(dataset_df['feature'].tolist())
y = np.array(dataset_df['label'].tolist())

X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.30, random_state=1, stratify=y)
X_test, X_val, Y_test, Y_val = train_test_split(X_test, Y_test, test_size=0.5, random_state=1, stratify=Y_test)

# %%
# Add dimension for the channel

X_train = X_train.reshape(-1,32,129,3)
X_val = X_val.reshape(-1,32,129,3)
X_test = X_test.reshape(-1,32,129,3)

print(X_train.shape, X_val.shape, X_test.shape)
# Out:
# (5097, 32, 129, 3) (1093, 32, 129, 3) (1092, 32, 129, 3)

# %%
# transfer learning

import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dropout, Dense, GlobalAveragePooling2D
from tensorflow.keras.applications import VGG16
# from tensorflow.keras.applications import VGG19
# from tensorflow.keras.applications import ResNet50
# from tensorflow.keras.applications import Xception
# from tensorflow.keras.applications import DenseNet121
# from tensorflow.keras.applications import MobileNet
# from tensorflow.keras.applications import NASNetLarge


pre_trained_model = VGG16(weights='imagenet', include_top=False, input_shape=(32,129,3))
pre_trained_model.summary()

model = Sequential()
model.add(pre_trained_model)
model.add(GlobalAveragePooling2D())
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))                          # 0.25 오버피팅 발생함
model.add(Dense(10, activation='softmax'))

model.compile(loss='categorical_crossentropy',
             optimizer=tf.keras.optimizers.Adam(2e-4), metrics=['acc'])
model.summary()
# Out:
# Model: "NASNet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 32, 129, 3)]         0         []
#
#  stem_conv1 (Conv2D)         (None, 15, 64, 96)           2592      ['input_1[0][0]']
#
#  stem_bn1 (BatchNormalizati  (None, 15, 64, 96)           384       ['stem_conv1[0][0]']
#  on)
#
#  activation (Activation)     (None, 15, 64, 96)           0         ['stem_bn1[0][0]']
#
#  reduction_conv_1_stem_1 (C  (None, 15, 64, 42)           4032      ['activation[0][0]']
#  onv2D)
#
#  reduction_bn_1_stem_1 (Bat  (None, 15, 64, 42)           168       ['reduction_conv_1_stem_1[0][0
#  chNormalization)                                                   ]']
#
#  activation_1 (Activation)   (None, 15, 64, 42)           0         ['reduction_bn_1_stem_1[0][0]'
#                                                                     ]
#
#  activation_3 (Activation)   (None, 15, 64, 96)           0         ['stem_bn1[0][0]']
#
#  separable_conv_1_pad_reduc  (None, 19, 67, 42)           0         ['activation_1[0][0]']
#  tion_left1_stem_1 (ZeroPad
#  ding2D)
#
#  separable_conv_1_pad_reduc  (None, 21, 69, 96)           0         ['activation_3[0][0]']
#  tion_right1_stem_1 (ZeroPa
#  dding2D)
#
#  separable_conv_1_reduction  (None, 8, 32, 42)            2814      ['separable_conv_1_pad_reducti
#  _left1_stem_1 (SeparableCo                                         on_left1_stem_1[0][0]']
#  nv2D)
#
#  separable_conv_1_reduction  (None, 8, 32, 42)            8736      ['separable_conv_1_pad_reducti
#  _right1_stem_1 (SeparableC                                         on_right1_stem_1[0][0]']
#  onv2D)
#
#  separable_conv_1_bn_reduct  (None, 8, 32, 42)            168       ['separable_conv_1_reduction_l
#  ion_left1_stem_1 (BatchNor                                         eft1_stem_1[0][0]']
#  malization)
#
#  separable_conv_1_bn_reduct  (None, 8, 32, 42)            168       ['separable_conv_1_reduction_r
#  ion_right1_stem_1 (BatchNo                                         ight1_stem_1[0][0]']
#  rmalization)
#
#  activation_2 (Activation)   (None, 8, 32, 42)            0         ['separable_conv_1_bn_reductio
#                                                                     n_left1_stem_1[0][0]']
#
#  activation_4 (Activation)   (None, 8, 32, 42)            0         ['separable_conv_1_bn_reductio
#                                                                     n_right1_stem_1[0][0]']
#
#  separable_conv_2_reduction  (None, 8, 32, 42)            2814      ['activation_2[0][0]']
#  _left1_stem_1 (SeparableCo
#  nv2D)
#
#  separable_conv_2_reduction  (None, 8, 32, 42)            3822      ['activation_4[0][0]']
#  _right1_stem_1 (SeparableC
#  onv2D)
#
#  activation_5 (Activation)   (None, 15, 64, 96)           0         ['stem_bn1[0][0]']
#
#  separable_conv_2_bn_reduct  (None, 8, 32, 42)            168       ['separable_conv_2_reduction_l
#  ion_left1_stem_1 (BatchNor                                         eft1_stem_1[0][0]']
#  malization)
#
#  separable_conv_2_bn_reduct  (None, 8, 32, 42)            168       ['separable_conv_2_reduction_r
#  ion_right1_stem_1 (BatchNo                                         ight1_stem_1[0][0]']
#  rmalization)
#
#  separable_conv_1_pad_reduc  (None, 21, 69, 96)           0         ['activation_5[0][0]']
#  tion_right2_stem_1 (ZeroPa
#  dding2D)
#
#  activation_7 (Activation)   (None, 15, 64, 96)           0         ['stem_bn1[0][0]']
#
#  reduction_add_1_stem_1 (Ad  (None, 8, 32, 42)            0         ['separable_conv_2_bn_reductio
#  d)                                                                 n_left1_stem_1[0][0]',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right1_stem_1[0][0]']
#
#  separable_conv_1_reduction  (None, 8, 32, 42)            8736      ['separable_conv_1_pad_reducti
#  _right2_stem_1 (SeparableC                                         on_right2_stem_1[0][0]']
#  onv2D)
#
#  separable_conv_1_pad_reduc  (None, 19, 67, 96)           0         ['activation_7[0][0]']
#  tion_right3_stem_1 (ZeroPa
#  dding2D)
#
#  activation_9 (Activation)   (None, 8, 32, 42)            0         ['reduction_add_1_stem_1[0][0]
#                                                                     ']
#
#  separable_conv_1_bn_reduct  (None, 8, 32, 42)            168       ['separable_conv_1_reduction_r
#  ion_right2_stem_1 (BatchNo                                         ight2_stem_1[0][0]']
#  rmalization)
#
#  separable_conv_1_reduction  (None, 8, 32, 42)            6432      ['separable_conv_1_pad_reducti
#  _right3_stem_1 (SeparableC                                         on_right3_stem_1[0][0]']
#  onv2D)
#
#  separable_conv_1_reduction  (None, 8, 32, 42)            2142      ['activation_9[0][0]']
#  _left4_stem_1 (SeparableCo
#  nv2D)
#
#  activation_6 (Activation)   (None, 8, 32, 42)            0         ['separable_conv_1_bn_reductio
#                                                                     n_right2_stem_1[0][0]']
#
#  separable_conv_1_bn_reduct  (None, 8, 32, 42)            168       ['separable_conv_1_reduction_r
#  ion_right3_stem_1 (BatchNo                                         ight3_stem_1[0][0]']
#  rmalization)
#
#  separable_conv_1_bn_reduct  (None, 8, 32, 42)            168       ['separable_conv_1_reduction_l
#  ion_left4_stem_1 (BatchNor                                         eft4_stem_1[0][0]']
#  malization)
#
#  reduction_pad_1_stem_1 (Ze  (None, 17, 65, 42)           0         ['reduction_bn_1_stem_1[0][0]'
#  roPadding2D)                                                       ]
#
#  separable_conv_2_reduction  (None, 8, 32, 42)            3822      ['activation_6[0][0]']
#  _right2_stem_1 (SeparableC
#  onv2D)
#
#  activation_8 (Activation)   (None, 8, 32, 42)            0         ['separable_conv_1_bn_reductio
#                                                                     n_right3_stem_1[0][0]']
#
#  activation_10 (Activation)  (None, 8, 32, 42)            0         ['separable_conv_1_bn_reductio
#                                                                     n_left4_stem_1[0][0]']
#
#  reduction_left2_stem_1 (Ma  (None, 8, 32, 42)            0         ['reduction_pad_1_stem_1[0][0]
#  xPooling2D)                                                        ']
#
#  separable_conv_2_bn_reduct  (None, 8, 32, 42)            168       ['separable_conv_2_reduction_r
#  ion_right2_stem_1 (BatchNo                                         ight2_stem_1[0][0]']
#  rmalization)
#
#  separable_conv_2_reduction  (None, 8, 32, 42)            2814      ['activation_8[0][0]']
#  _right3_stem_1 (SeparableC
#  onv2D)
#
#  separable_conv_2_reduction  (None, 8, 32, 42)            2142      ['activation_10[0][0]']
#  _left4_stem_1 (SeparableCo
#  nv2D)
#
#  adjust_relu_1_stem_2 (Acti  (None, 15, 64, 96)           0         ['stem_bn1[0][0]']
#  vation)
#
#  reduction_add_2_stem_1 (Ad  (None, 8, 32, 42)            0         ['reduction_left2_stem_1[0][0]
#  d)                                                                 ',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right2_stem_1[0][0]']
#
#  reduction_left3_stem_1 (Av  (None, 8, 32, 42)            0         ['reduction_pad_1_stem_1[0][0]
#  eragePooling2D)                                                    ']
#
#  separable_conv_2_bn_reduct  (None, 8, 32, 42)            168       ['separable_conv_2_reduction_r
#  ion_right3_stem_1 (BatchNo                                         ight3_stem_1[0][0]']
#  rmalization)
#
#  reduction_left4_stem_1 (Av  (None, 8, 32, 42)            0         ['reduction_add_1_stem_1[0][0]
#  eragePooling2D)                                                    ']
#
#  separable_conv_2_bn_reduct  (None, 8, 32, 42)            168       ['separable_conv_2_reduction_l
#  ion_left4_stem_1 (BatchNor                                         eft4_stem_1[0][0]']
#  malization)
#
#  reduction_right5_stem_1 (M  (None, 8, 32, 42)            0         ['reduction_pad_1_stem_1[0][0]
#  axPooling2D)                                                       ']
#
#  zero_padding2d (ZeroPaddin  (None, 16, 65, 96)           0         ['adjust_relu_1_stem_2[0][0]']
#  g2D)
#
#  reduction_add3_stem_1 (Add  (None, 8, 32, 42)            0         ['reduction_left3_stem_1[0][0]
#  )                                                                  ',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right3_stem_1[0][0]']
#
#  add (Add)                   (None, 8, 32, 42)            0         ['reduction_add_2_stem_1[0][0]
#                                                                     ',
#                                                                      'reduction_left4_stem_1[0][0]
#                                                                     ']
#
#  reduction_add4_stem_1 (Add  (None, 8, 32, 42)            0         ['separable_conv_2_bn_reductio
#  )                                                                  n_left4_stem_1[0][0]',
#                                                                      'reduction_right5_stem_1[0][0
#                                                                     ]']
#
#  cropping2d (Cropping2D)     (None, 15, 64, 96)           0         ['zero_padding2d[0][0]']
#
#  reduction_concat_stem_1 (C  (None, 8, 32, 168)           0         ['reduction_add_2_stem_1[0][0]
#  oncatenate)                                                        ',
#                                                                      'reduction_add3_stem_1[0][0]'
#                                                                     , 'add[0][0]',
#                                                                      'reduction_add4_stem_1[0][0]'
#                                                                     ]
#
#  adjust_avg_pool_1_stem_2 (  (None, 8, 32, 96)            0         ['adjust_relu_1_stem_2[0][0]']
#  AveragePooling2D)
#
#  adjust_avg_pool_2_stem_2 (  (None, 8, 32, 96)            0         ['cropping2d[0][0]']
#  AveragePooling2D)
#
#  activation_11 (Activation)  (None, 8, 32, 168)           0         ['reduction_concat_stem_1[0][0
#                                                                     ]']
#
#  adjust_conv_1_stem_2 (Conv  (None, 8, 32, 42)            4032      ['adjust_avg_pool_1_stem_2[0][
#  2D)                                                                0]']
#
#  adjust_conv_2_stem_2 (Conv  (None, 8, 32, 42)            4032      ['adjust_avg_pool_2_stem_2[0][
#  2D)                                                                0]']
#
#  reduction_conv_1_stem_2 (C  (None, 8, 32, 84)            14112     ['activation_11[0][0]']
#  onv2D)
#
#  concatenate (Concatenate)   (None, 8, 32, 84)            0         ['adjust_conv_1_stem_2[0][0]',
#                                                                      'adjust_conv_2_stem_2[0][0]']
#
#  reduction_bn_1_stem_2 (Bat  (None, 8, 32, 84)            336       ['reduction_conv_1_stem_2[0][0
#  chNormalization)                                                   ]']
#
#  adjust_bn_stem_2 (BatchNor  (None, 8, 32, 84)            336       ['concatenate[0][0]']
#  malization)
#
#  activation_12 (Activation)  (None, 8, 32, 84)            0         ['reduction_bn_1_stem_2[0][0]'
#                                                                     ]
#
#  activation_14 (Activation)  (None, 8, 32, 84)            0         ['adjust_bn_stem_2[0][0]']
#
#  separable_conv_1_pad_reduc  (None, 11, 35, 84)           0         ['activation_12[0][0]']
#  tion_left1_stem_2 (ZeroPad
#  ding2D)
#
#  separable_conv_1_pad_reduc  (None, 13, 37, 84)           0         ['activation_14[0][0]']
#  tion_right1_stem_2 (ZeroPa
#  dding2D)
#
#  separable_conv_1_reduction  (None, 4, 16, 84)            9156      ['separable_conv_1_pad_reducti
#  _left1_stem_2 (SeparableCo                                         on_left1_stem_2[0][0]']
#  nv2D)
#
#  separable_conv_1_reduction  (None, 4, 16, 84)            11172     ['separable_conv_1_pad_reducti
#  _right1_stem_2 (SeparableC                                         on_right1_stem_2[0][0]']
#  onv2D)
#
#  separable_conv_1_bn_reduct  (None, 4, 16, 84)            336       ['separable_conv_1_reduction_l
#  ion_left1_stem_2 (BatchNor                                         eft1_stem_2[0][0]']
#  malization)
#
#  separable_conv_1_bn_reduct  (None, 4, 16, 84)            336       ['separable_conv_1_reduction_r
#  ion_right1_stem_2 (BatchNo                                         ight1_stem_2[0][0]']
#  rmalization)
#
#  activation_13 (Activation)  (None, 4, 16, 84)            0         ['separable_conv_1_bn_reductio
#                                                                     n_left1_stem_2[0][0]']
#
#  activation_15 (Activation)  (None, 4, 16, 84)            0         ['separable_conv_1_bn_reductio
#                                                                     n_right1_stem_2[0][0]']
#
#  separable_conv_2_reduction  (None, 4, 16, 84)            9156      ['activation_13[0][0]']
#  _left1_stem_2 (SeparableCo
#  nv2D)
#
#  separable_conv_2_reduction  (None, 4, 16, 84)            11172     ['activation_15[0][0]']
#  _right1_stem_2 (SeparableC
#  onv2D)
#
#  activation_16 (Activation)  (None, 8, 32, 84)            0         ['adjust_bn_stem_2[0][0]']
#
#  separable_conv_2_bn_reduct  (None, 4, 16, 84)            336       ['separable_conv_2_reduction_l
#  ion_left1_stem_2 (BatchNor                                         eft1_stem_2[0][0]']
#  malization)
#
#  separable_conv_2_bn_reduct  (None, 4, 16, 84)            336       ['separable_conv_2_reduction_r
#  ion_right1_stem_2 (BatchNo                                         ight1_stem_2[0][0]']
#  rmalization)
#
#  separable_conv_1_pad_reduc  (None, 13, 37, 84)           0         ['activation_16[0][0]']
#  tion_right2_stem_2 (ZeroPa
#  dding2D)
#
#  activation_18 (Activation)  (None, 8, 32, 84)            0         ['adjust_bn_stem_2[0][0]']
#
#  reduction_add_1_stem_2 (Ad  (None, 4, 16, 84)            0         ['separable_conv_2_bn_reductio
#  d)                                                                 n_left1_stem_2[0][0]',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right1_stem_2[0][0]']
#
#  separable_conv_1_reduction  (None, 4, 16, 84)            11172     ['separable_conv_1_pad_reducti
#  _right2_stem_2 (SeparableC                                         on_right2_stem_2[0][0]']
#  onv2D)
#
#  separable_conv_1_pad_reduc  (None, 11, 35, 84)           0         ['activation_18[0][0]']
#  tion_right3_stem_2 (ZeroPa
#  dding2D)
#
#  activation_20 (Activation)  (None, 4, 16, 84)            0         ['reduction_add_1_stem_2[0][0]
#                                                                     ']
#
#  separable_conv_1_bn_reduct  (None, 4, 16, 84)            336       ['separable_conv_1_reduction_r
#  ion_right2_stem_2 (BatchNo                                         ight2_stem_2[0][0]']
#  rmalization)
#
#  separable_conv_1_reduction  (None, 4, 16, 84)            9156      ['separable_conv_1_pad_reducti
#  _right3_stem_2 (SeparableC                                         on_right3_stem_2[0][0]']
#  onv2D)
#
#  separable_conv_1_reduction  (None, 4, 16, 84)            7812      ['activation_20[0][0]']
#  _left4_stem_2 (SeparableCo
#  nv2D)
#
#  activation_17 (Activation)  (None, 4, 16, 84)            0         ['separable_conv_1_bn_reductio
#                                                                     n_right2_stem_2[0][0]']
#
#  separable_conv_1_bn_reduct  (None, 4, 16, 84)            336       ['separable_conv_1_reduction_r
#  ion_right3_stem_2 (BatchNo                                         ight3_stem_2[0][0]']
#  rmalization)
#
#  separable_conv_1_bn_reduct  (None, 4, 16, 84)            336       ['separable_conv_1_reduction_l
#  ion_left4_stem_2 (BatchNor                                         eft4_stem_2[0][0]']
#  malization)
#
#  reduction_pad_1_stem_2 (Ze  (None, 9, 33, 84)            0         ['reduction_bn_1_stem_2[0][0]'
#  roPadding2D)                                                       ]
#
#  separable_conv_2_reduction  (None, 4, 16, 84)            11172     ['activation_17[0][0]']
#  _right2_stem_2 (SeparableC
#  onv2D)
#
#  activation_19 (Activation)  (None, 4, 16, 84)            0         ['separable_conv_1_bn_reductio
#                                                                     n_right3_stem_2[0][0]']
#
#  activation_21 (Activation)  (None, 4, 16, 84)            0         ['separable_conv_1_bn_reductio
#                                                                     n_left4_stem_2[0][0]']
#
#  reduction_left2_stem_2 (Ma  (None, 4, 16, 84)            0         ['reduction_pad_1_stem_2[0][0]
#  xPooling2D)                                                        ']
#
#  separable_conv_2_bn_reduct  (None, 4, 16, 84)            336       ['separable_conv_2_reduction_r
#  ion_right2_stem_2 (BatchNo                                         ight2_stem_2[0][0]']
#  rmalization)
#
#  separable_conv_2_reduction  (None, 4, 16, 84)            9156      ['activation_19[0][0]']
#  _right3_stem_2 (SeparableC
#  onv2D)
#
#  separable_conv_2_reduction  (None, 4, 16, 84)            7812      ['activation_21[0][0]']
#  _left4_stem_2 (SeparableCo
#  nv2D)
#
#  adjust_relu_1_0 (Activatio  (None, 8, 32, 168)           0         ['reduction_concat_stem_1[0][0
#  n)                                                                 ]']
#
#  reduction_add_2_stem_2 (Ad  (None, 4, 16, 84)            0         ['reduction_left2_stem_2[0][0]
#  d)                                                                 ',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right2_stem_2[0][0]']
#
#  reduction_left3_stem_2 (Av  (None, 4, 16, 84)            0         ['reduction_pad_1_stem_2[0][0]
#  eragePooling2D)                                                    ']
#
#  separable_conv_2_bn_reduct  (None, 4, 16, 84)            336       ['separable_conv_2_reduction_r
#  ion_right3_stem_2 (BatchNo                                         ight3_stem_2[0][0]']
#  rmalization)
#
#  reduction_left4_stem_2 (Av  (None, 4, 16, 84)            0         ['reduction_add_1_stem_2[0][0]
#  eragePooling2D)                                                    ']
#
#  separable_conv_2_bn_reduct  (None, 4, 16, 84)            336       ['separable_conv_2_reduction_l
#  ion_left4_stem_2 (BatchNor                                         eft4_stem_2[0][0]']
#  malization)
#
#  reduction_right5_stem_2 (M  (None, 4, 16, 84)            0         ['reduction_pad_1_stem_2[0][0]
#  axPooling2D)                                                       ']
#
#  zero_padding2d_1 (ZeroPadd  (None, 9, 33, 168)           0         ['adjust_relu_1_0[0][0]']
#  ing2D)
#
#  reduction_add3_stem_2 (Add  (None, 4, 16, 84)            0         ['reduction_left3_stem_2[0][0]
#  )                                                                  ',
#                                                                      'separable_conv_2_bn_reductio
#                                                                     n_right3_stem_2[0][0]']
#
#  add_1 (Add)                 (None, 4, 16, 84)            0         ['reduction_add_2_stem_2[0][0]
#                                                                     ',
#                                                                      'reduction_left4_stem_2[0][0]
#                                                                     ']
#
#  reduction_add4_stem_2 (Add  (None, 4, 16, 84)            0         ['separable_conv_2_bn_reductio
#  )                                                                  n_left4_stem_2[0][0]',
#                                                                      'reduction_right5_stem_2[0][0
#                                                                     ]']
#
#  cropping2d_1 (Cropping2D)   (None, 8, 32, 168)           0         ['zero_padding2d_1[0][0]']
#
#  reduction_concat_stem_2 (C  (None, 4, 16, 336)           0         ['reduction_add_2_stem_2[0][0]
#  oncatenate)                                                        ',
#                                                                      'reduction_add3_stem_2[0][0]'
#                                                                     , 'add_1[0][0]',
#                                                                      'reduction_add4_stem_2[0][0]'
#                                                                     ]
#
#  adjust_avg_pool_1_0 (Avera  (None, 4, 16, 168)           0         ['adjust_relu_1_0[0][0]']
#  gePooling2D)
#
#  adjust_avg_pool_2_0 (Avera  (None, 4, 16, 168)           0         ['cropping2d_1[0][0]']
#  gePooling2D)
#
#  adjust_conv_1_0 (Conv2D)    (None, 4, 16, 84)            14112     ['adjust_avg_pool_1_0[0][0]']
#
#  adjust_conv_2_0 (Conv2D)    (None, 4, 16, 84)            14112     ['adjust_avg_pool_2_0[0][0]']
#
#  activation_22 (Activation)  (None, 4, 16, 336)           0         ['reduction_concat_stem_2[0][0
#                                                                     ]']
#
#  concatenate_1 (Concatenate  (None, 4, 16, 168)           0         ['adjust_conv_1_0[0][0]',
#  )                                                                   'adjust_conv_2_0[0][0]']
#
#  normal_conv_1_0 (Conv2D)    (None, 4, 16, 168)           56448     ['activation_22[0][0]']
#
#  adjust_bn_0 (BatchNormaliz  (None, 4, 16, 168)           672       ['concatenate_1[0][0]']
#  ation)
#
#  normal_bn_1_0 (BatchNormal  (None, 4, 16, 168)           672       ['normal_conv_1_0[0][0]']
#  ization)
#
#  activation_23 (Activation)  (None, 4, 16, 168)           0         ['normal_bn_1_0[0][0]']
#
#  activation_25 (Activation)  (None, 4, 16, 168)           0         ['adjust_bn_0[0][0]']
#
#  activation_27 (Activation)  (None, 4, 16, 168)           0         ['adjust_bn_0[0][0]']
#
#  activation_29 (Activation)  (None, 4, 16, 168)           0         ['adjust_bn_0[0][0]']
#
#  activation_31 (Activation)  (None, 4, 16, 168)           0         ['normal_bn_1_0[0][0]']
#
#  separable_conv_1_normal_le  (None, 4, 16, 168)           32424     ['activation_23[0][0]']
#  ft1_0 (SeparableConv2D)
#
#  separable_conv_1_normal_ri  (None, 4, 16, 168)           29736     ['activation_25[0][0]']
#  ght1_0 (SeparableConv2D)
#
#  separable_conv_1_normal_le  (None, 4, 16, 168)           32424     ['activation_27[0][0]']
#  ft2_0 (SeparableConv2D)
#
#  separable_conv_1_normal_ri  (None, 4, 16, 168)           29736     ['activation_29[0][0]']
#  ght2_0 (SeparableConv2D)
#
#  separable_conv_1_normal_le  (None, 4, 16, 168)           29736     ['activation_31[0][0]']
#  ft5_0 (SeparableConv2D)
#
#  separable_conv_1_bn_normal  (None, 4, 16, 168)           672       ['separable_conv_1_normal_left
#  _left1_0 (BatchNormalizati                                         1_0[0][0]']
#  on)
#
#  separable_conv_1_bn_normal  (None, 4, 16, 168)           672       ['separable_conv_1_normal_righ
#  _right1_0 (BatchNormalizat                                         t1_0[0][0]']
#  ion)
#
#  separable_conv_1_bn_normal  (None, 4, 16, 168)           672       ['separable_conv_1_normal_left
#  _left2_0 (BatchNormalizati                                         2_0[0][0]']
#  on)
#
#  separable_conv_1_bn_normal  (None, 4, 16, 168)           672       ['separable_conv_1_normal_righ
#  _right2_0 (BatchNormalizat                                         t2_0[0][0]']
#  ion)
#
#  separable_conv_1_bn_normal  (None, 4, 16, 168)           672       ['separable_conv_1_normal_left
#  _left5_0 (BatchNormalizati                                         5_0[0][0]']
#  on)
#
#  activation_24 (Activation)  (None, 4, 16, 168)           0         ['separable_conv_1_bn_normal_l
#                                                                     eft1_0[0][0]']
#
#  activation_26 (Activation)  (None, 4, 16, 168)           0         ['separable_conv_1_bn_normal_r
#                                                                     ight1_0[0][0]']
#
#  activation_28 (Activation)  (None, 4, 16, 168)           0         ['separable_conv_1_bn_normal_l
#                                                                     eft2_0[0][0]']
#
#  activation_30 (Activation)  (None, 4, 16, 168)           0         ['separable_conv_1_bn_normal_r
#                                                                     ight2_0[0][0]']
#
#  activation_32 (Activation)  (None, 4, 16, 168)           0         ['separable_conv_1_bn_normal_l
#                                                                     eft5_0[0][0]']
# ...
#
#  adjust_bn_18 (BatchNormali  (None, 1, 4, 672)            2688      ['adjust_conv_projection_18[0]
#  zation)                                                            [0]']
#
#  normal_bn_1_18 (BatchNorma  (None, 1, 4, 672)            2688      ['normal_conv_1_18[0][0]']
#  lization)
#
#  activation_249 (Activation  (None, 1, 4, 672)            0         ['normal_bn_1_18[0][0]']
#  )
#
#  activation_251 (Activation  (None, 1, 4, 672)            0         ['adjust_bn_18[0][0]']
#  )
#
#  activation_253 (Activation  (None, 1, 4, 672)            0         ['adjust_bn_18[0][0]']
#  )
#
#  activation_255 (Activation  (None, 1, 4, 672)            0         ['adjust_bn_18[0][0]']
#  )
#
#  activation_257 (Activation  (None, 1, 4, 672)            0         ['normal_bn_1_18[0][0]']
#  )
#
#  separable_conv_1_normal_le  (None, 1, 4, 672)            468384    ['activation_249[0][0]']
#  ft1_18 (SeparableConv2D)
#
#  separable_conv_1_normal_ri  (None, 1, 4, 672)            457632    ['activation_251[0][0]']
#  ght1_18 (SeparableConv2D)
#
#  separable_conv_1_normal_le  (None, 1, 4, 672)            468384    ['activation_253[0][0]']
#  ft2_18 (SeparableConv2D)
#
#  separable_conv_1_normal_ri  (None, 1, 4, 672)            457632    ['activation_255[0][0]']
#  ght2_18 (SeparableConv2D)
#
#  separable_conv_1_normal_le  (None, 1, 4, 672)            457632    ['activation_257[0][0]']
#  ft5_18 (SeparableConv2D)
#
#  separable_conv_1_bn_normal  (None, 1, 4, 672)            2688      ['separable_conv_1_normal_left
#  _left1_18 (BatchNormalizat                                         1_18[0][0]']
#  ion)
#
#  separable_conv_1_bn_normal  (None, 1, 4, 672)            2688      ['separable_conv_1_normal_righ
#  _right1_18 (BatchNormaliza                                         t1_18[0][0]']
#  tion)
#
#  separable_conv_1_bn_normal  (None, 1, 4, 672)            2688      ['separable_conv_1_normal_left
#  _left2_18 (BatchNormalizat                                         2_18[0][0]']
#  ion)
#
#  separable_conv_1_bn_normal  (None, 1, 4, 672)            2688      ['separable_conv_1_normal_righ
#  _right2_18 (BatchNormaliza                                         t2_18[0][0]']
#  tion)
#
#  separable_conv_1_bn_normal  (None, 1, 4, 672)            2688      ['separable_conv_1_normal_left
#  _left5_18 (BatchNormalizat                                         5_18[0][0]']
#  ion)
#
#  activation_250 (Activation  (None, 1, 4, 672)            0         ['separable_conv_1_bn_normal_l
#  )                                                                  eft1_18[0][0]']
#
#  activation_252 (Activation  (None, 1, 4, 672)            0         ['separable_conv_1_bn_normal_r
#  )                                                                  ight1_18[0][0]']
#
#  activation_254 (Activation  (None, 1, 4, 672)            0         ['separable_conv_1_bn_normal_l
#  )                                                                  eft2_18[0][0]']
#
#  activation_256 (Activation  (None, 1, 4, 672)            0         ['separable_conv_1_bn_normal_r
#  )                                                                  ight2_18[0][0]']
#
#  activation_258 (Activation  (None, 1, 4, 672)            0         ['separable_conv_1_bn_normal_l
#  )                                                                  eft5_18[0][0]']
#
#  separable_conv_2_normal_le  (None, 1, 4, 672)            468384    ['activation_250[0][0]']
#  ft1_18 (SeparableConv2D)
#
#  separable_conv_2_normal_ri  (None, 1, 4, 672)            457632    ['activation_252[0][0]']
#  ght1_18 (SeparableConv2D)
#
#  separable_conv_2_normal_le  (None, 1, 4, 672)            468384    ['activation_254[0][0]']
#  ft2_18 (SeparableConv2D)
#
#  separable_conv_2_normal_ri  (None, 1, 4, 672)            457632    ['activation_256[0][0]']
#  ght2_18 (SeparableConv2D)
#
#  separable_conv_2_normal_le  (None, 1, 4, 672)            457632    ['activation_258[0][0]']
#  ft5_18 (SeparableConv2D)
#
#  separable_conv_2_bn_normal  (None, 1, 4, 672)            2688      ['separable_conv_2_normal_left
#  _left1_18 (BatchNormalizat                                         1_18[0][0]']
#  ion)
#
#  separable_conv_2_bn_normal  (None, 1, 4, 672)            2688      ['separable_conv_2_normal_righ
#  _right1_18 (BatchNormaliza                                         t1_18[0][0]']
#  tion)
#
#  separable_conv_2_bn_normal  (None, 1, 4, 672)            2688      ['separable_conv_2_normal_left
#  _left2_18 (BatchNormalizat                                         2_18[0][0]']
#  ion)
#
#  separable_conv_2_bn_normal  (None, 1, 4, 672)            2688      ['separable_conv_2_normal_righ
#  _right2_18 (BatchNormaliza                                         t2_18[0][0]']
#  tion)
#
#  normal_left3_18 (AveragePo  (None, 1, 4, 672)            0         ['normal_bn_1_18[0][0]']
#  oling2D)
#
#  normal_left4_18 (AveragePo  (None, 1, 4, 672)            0         ['adjust_bn_18[0][0]']
#  oling2D)
#
#  normal_right4_18 (AverageP  (None, 1, 4, 672)            0         ['adjust_bn_18[0][0]']
#  ooling2D)
#
#  separable_conv_2_bn_normal  (None, 1, 4, 672)            2688      ['separable_conv_2_normal_left
#  _left5_18 (BatchNormalizat                                         5_18[0][0]']
#  ion)
#
#  normal_add_1_18 (Add)       (None, 1, 4, 672)            0         ['separable_conv_2_bn_normal_l
#                                                                     eft1_18[0][0]',
#                                                                      'separable_conv_2_bn_normal_r
#                                                                     ight1_18[0][0]']
#
#  normal_add_2_18 (Add)       (None, 1, 4, 672)            0         ['separable_conv_2_bn_normal_l
#                                                                     eft2_18[0][0]',
#                                                                      'separable_conv_2_bn_normal_r
#                                                                     ight2_18[0][0]']
#
#  normal_add_3_18 (Add)       (None, 1, 4, 672)            0         ['normal_left3_18[0][0]',
#                                                                      'adjust_bn_18[0][0]']
#
#  normal_add_4_18 (Add)       (None, 1, 4, 672)            0         ['normal_left4_18[0][0]',
#                                                                      'normal_right4_18[0][0]']
#
#  normal_add_5_18 (Add)       (None, 1, 4, 672)            0         ['separable_conv_2_bn_normal_l
#                                                                     eft5_18[0][0]',
#                                                                      'normal_bn_1_18[0][0]']
#
#  normal_concat_18 (Concaten  (None, 1, 4, 4032)           0         ['adjust_bn_18[0][0]',
#  ate)                                                                'normal_add_1_18[0][0]',
#                                                                      'normal_add_2_18[0][0]',
#                                                                      'normal_add_3_18[0][0]',
#                                                                      'normal_add_4_18[0][0]',
#                                                                      'normal_add_5_18[0][0]']
#
#  activation_259 (Activation  (None, 1, 4, 4032)           0         ['normal_concat_18[0][0]']
#  )
#
# ==================================================================================================
# Total params: 84916818 (323.93 MB)
# Trainable params: 84720150 (323.18 MB)
# Non-trainable params: 196668 (768.23 KB)
# __________________________________________________________________________________________________
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  NASNet (Functional)         (None, 1, 4, 4032)        84916818
#
#  global_average_pooling2d (  (None, 4032)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 64)                258112
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 85175580 (324.92 MB)
# Trainable params: 84978912 (324.17 MB)
# Non-trainable params: 196668 (768.23 KB)
# _________________________________________________________________

# %%
# callbacks

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

checkpoint = ModelCheckpoint(filepath='best_fcn.hdf5', # filename
                                monitor='val_acc',   # val_accuracy 값이 개선되었을때 호출
                                verbose=1,                # 로그 출력
                                save_best_only=True,      # 가장 best 값 저장
                                mode='auto')              # 알아서 best 찾음

earlystopping = EarlyStopping(monitor='val_loss',  # 모니터 기준 설정 (val loss)
                               patience=5,        # 3회 Epoch동안 개선되지 않는다면 종료
                               verbose=1
                              )

# checkpointer = ModelCheckpoint(filepath='best_fcn.hdf5',
#                                monitor='val_accuracy', verbose=1,
#                                save_best_only=True)

#callbacks = [checkpoint, earlystopping]
callbacks = [checkpoint]

# %%
# run model

epochs = 150
batch_size = 256

hist = model.fit(X_train, Y_train,
              batch_size=batch_size, epochs=epochs,
              validation_data=(X_val, Y_val), callbacks=callbacks,
              verbose=1)
# Out:
# Epoch 1/150
# 20/20 [==============================] - ETA: 0s - loss: 2.1637 - acc: 0.2219
# Epoch 1: val_acc improved from -inf to 0.12260, saving model to best_fcn.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 20/20 [==============================] - 276s 4s/step - loss: 2.1637 - acc: 0.2219 - val_loss: 6.3257 - val_acc: 0.1226
# Epoch 2/150
# 20/20 [==============================] - ETA: 0s - loss: 1.5049 - acc: 0.4866
# Epoch 2: val_acc did not improve from 0.12260
# 20/20 [==============================] - 36s 2s/step - loss: 1.5049 - acc: 0.4866 - val_loss: 4.9477 - val_acc: 0.1180
# Epoch 3/150
# 20/20 [==============================] - ETA: 0s - loss: 0.9773 - acc: 0.6731
# Epoch 3: val_acc improved from 0.12260 to 0.16377, saving model to best_fcn.hdf5
150
# 20/20 [==============================] - ETA: 0s - loss: 0.0149 - acc: 0.9971
# Epoch 40: val_acc did not improve from 0.20220
# 20/20 [==============================] - 37s 2s/step - loss: 0.0149 - acc: 0.9971 - val_loss: 4.6758 - val_acc: 0.1400
# Epoch 41/150
# 20/20 [==============================] - ETA: 0s - loss: 0.0134 - acc: 0.9971
# Epoch 41: val_acc did not improve from 0.20220
# 20/20 [==============================] - 39s 2s/step - loss: 0.0134 - acc: 0.9971 - val_loss: 4.7035 - val_acc: 0.1391
# Epoch 42/150
# 20/20 [==============================] - ETA: 0s - loss: 0.0123 - acc: 0.9973
# Epoch 42: val_acc did not improve from 0.20220
# 20/20 [==============================] - 37s 2s/step - loss: 0.0123 - acc: 0.9973 - val_loss: 5.0449 - val_acc: 0.1391
# Epoch 43/150
# 20/20 [==============================] - ETA: 0s - loss: 0.0108 - acc: 0.9980
# Epoch 43: val_acc did not improve from 0.20220
# 20/20 [==============================] - 37s 2s/step - loss: 0.0108 - acc: 0.9980 - val_loss: 4.3323 - val_acc: 0.1327
# Epoch 44/150
# 20/20 [==============================] - ETA: 0s - loss: 0.0109 - acc: 0.9978
# Epoch 44: val_acc did not improve from 0.20220
# 20/20 [==============================] - 37s 2s/step - loss: 0.0109 - acc: 0.9978 - val_loss: 5.1365 - val_acc: 0.1482
# Epoch 45/150
# 20/20 [==============================] - ETA: 0s - loss: 0.0102 - acc: 0.9976
# Epoch 45: val_acc did not improve from 0.20220
# 20/20 [==============================] - 37s 2s/step - loss: 0.0102 - acc: 0.9976 - val_loss: 6.8719 - val_acc: 0.1400
# Epoch 46/150
# 20/20 [==============================] - ETA: 0s - loss: 0.0236 - acc: 0.9957
# Epoch 46: val_acc did not improve from 0.20220
# 20/20 [==============================] - 39s 2s/step - loss: 0.0236 - acc: 0.9957 - val_loss: 9.3510 - val_acc: 0.1455
# Epoch 47/150
# 20/20 [==============================] - ETA: 0s - loss: 0.0275 - acc: 0.9931
# Epoch 47: val_acc did not improve from 0.20220
# 20/20 [==============================] - 37s 2s/step - loss: 0.0275 - acc: 0.9931 - val_loss: 7.6750 - val_acc: 0.1619
# Epoch 48/150
# 20/20 [==============================] - ETA: 0s - loss: 0.0487 - acc: 0.9916
# Epoch 48: val_acc did not improve from 0.20220
# 20/20 [==============================] - 37s 2s/step - loss: 0.0487 - acc: 0.9916 - val_loss: 7.6377 - val_acc: 0.1528
# Epoch 49/150
# 20/20 [==============================] - ETA: 0s - loss: 0.0235 - acc: 0.9953
# Epoch 49: val_acc did not improve from 0.20220
# 20/20 [==============================] - 39s 2s/step - loss: 0.0235 - acc: 0.9953 - val_loss: 7.5939 - val_acc: 0.1583
# Epoch 50/150
# 20/20 [==============================] - ETA: 0s - loss: 0.0224 - acc: 0.9971
# Epoch 50: val_acc did not improve from 0.20220
# 20/20 [==============================] - 37s 2s/step - loss: 0.0224 - acc: 0.9971 - val_loss: 5.7907 - val_acc: 0.1812
# Epoch 51/150
# 20/20 [==============================] - ETA: 0s - loss: 0.0241 - acc: 0.9951
# Epoch 51: val_acc did not improve from 0.20220
# 20/20 [==============================] - 39s 2s/step - loss: 0.0241 - acc: 0.9951 - val_loss: 6.2539 - val_acc: 0.1802
# Epoch 52/150
# 20/20 [==============================] - ETA: 0s - loss: 0.0169 - acc: 0.9961
# Epoch 52: val_acc did not improve from 0.20220
# 20/20 [==============================] - 37s 2s/step - loss: 0.0169 - acc: 0.9961 - val_loss: 7.2286 - val_acc: 0.1757
# Epoch 53/150
# 20/20 [==============================] - ETA: 0s - loss: 0.0163 - acc: 0.9963
# Epoch 53: val_acc did not improve from 0.20220
# 20/20 [==============================] - 37s 2s/step - loss: 0.0163 - acc: 0.9963 - val_loss: 6.8927 - val_acc: 0.1839
# Epoch 54/150
# 20/20 [==============================] - ETA: 0s - loss: 0.0274 - acc: 0.9949
# Epoch 54: val_acc did not improve from 0.20220
# 20/20 [==============================] - 39s 2s/step - loss: 0.0274 - acc: 0.9949 - val_loss: 8.2973 - val_acc: 0.1802
# Epoch 55/150
# 20/20 [==============================] - ETA: 0s - loss: 0.0423 - acc: 0.9902
# Epoch 55: val_acc did not improve from 0.20220
# 20/20 [==============================] - 37s 2s/step - loss: 0.0423 - acc: 0.9902 - val_loss: 8.4629 - val_acc: 0.1711
# Epoch 56/150
# 14/20 [====================>.........] - ETA: 10s - loss: 0.0261 - acc: 0.9922

# %%
# Evaluating the model on the training and testing set

best_model = load_model('best_fcn.hdf5')
score = best_model.evaluate(X_train, Y_train, verbose=0)
print("Training Accuracy: ", score[1])
score = best_model.evaluate(X_val, Y_val, verbose=0)
print("Validation Accuracy: ", score[1])
score = best_model.evaluate(X_test, Y_test, verbose=0)
print("Testing Accuracy: ", score[1])

# %%
# plot trend of accuracy & loss

import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14,6))
ax1 = plt.subplot(1,2,1)
ax1.plot(hist.history['acc'], label='train')
ax1.plot(hist.history['val_acc'], label='validation')
ax1.set_title('Accuracy Trend')
ax1.set_ylabel('accuracy')
ax1.set_xlabel('epoch')
ax1.legend(loc='best')
ax1.grid()
ax2 = plt.subplot(1,2,2)
ax2.plot(hist.history['loss'], label='train')
ax2.plot(hist.history['val_loss'], label='validation')
ax2.set_title('Loss Trend')
ax2.set_ylabel('loss')
ax2.set_xlabel('epoch')
ax2.legend(loc='best')
ax2.grid()
plt.show()

# %%
# plot confusion matrix

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

Y_pred = best_model.predict(X_test)
cm = confusion_matrix(Y_test.argmax(axis=1), Y_pred.argmax(axis=1))

class_dic = {3: 'dog_bark', 2: 'children_playing', 1: 'car_horn',
              0: 'air_conditioner', 9: 'street_music', 6: 'gun_shot',
              8: 'siren', 5: 'engine_idling', 7: 'jackhammer', 4: 'drilling'}
classes = [class_dic[key] for key in sorted(class_dic.keys())]

normalize = True

if normalize:
    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

df_cm = pd.DataFrame(cm, index =[i for i in classes],columns=[i for i in classes])

plt.figure(figsize=(16,12))
plt.title('Confusion Matrix')
sns.heatmap(df_cm,annot=True)

# %%
# Plot a confusion matrix

from sklearn import metrics

Y_pred = best_model.predict(X_test)
matrix = metrics.confusion_matrix(Y_test.argmax(axis=1), Y_pred.argmax(axis=1))

# Confusion matrix code (from https://github.com/triagemd/keras-eval/blob/master/keras_eval/visualizer.py)
def plot_confusion_matrix(cm, concepts, normalize=False, show_text=True, fontsize=18, figsize=(16, 12),
                          cmap=plt.cm.coolwarm_r, save_path=None, show_labels=True):

    if cm.ndim != 2 or cm.shape[0] != cm.shape[1]:
        raise ValueError('Invalid confusion matrix shape, it should be square and ndim=2')

    if cm.shape[0] != len(concepts) or cm.shape[1] != len(concepts):
        raise ValueError('Number of concepts (%i) and dimensions of confusion matrix do not coincide (%i, %i)' %
                          (len(concepts), cm.shape[0], cm.shape[1]))

    plt.rcParams.update({'font.size': fontsize})

    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    if normalize:
        cm = cm_normalized
        print(cm)

    fig = plt.figure(figsize=figsize)
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm, vmin=np.min(cm), vmax=np.max(cm), alpha=0.8, cmap=cmap)

    fig.colorbar(cax)
    ax.xaxis.tick_bottom()
    plt.ylabel('True label', fontweight='bold')
    plt.xlabel('Predicted label', fontweight='bold')

    if show_labels:
        n_labels = len(concepts)
        ax.set_xticklabels(concepts)
        ax.set_yticklabels(concepts)
#         plt.xticks(np.arange(0, n_labels, 1.0), rotation='vertical')
        plt.xticks(np.arange(0, n_labels, 1.0), rotation=45)
        plt.yticks(np.arange(0, n_labels, 1.0))
    else:
        plt.axis('off')

    fmt = '.2f' if normalize else 'd'
    if show_text:
        # http://stackoverflow.com/questions/21712047/matplotlib-imshow-matshow-display-values-on-plot
        min_val, max_val = 0, len(concepts)
        ind_array = np.arange(min_val, max_val, 1.0)
        x, y = np.meshgrid(ind_array, ind_array)
        for i, (x_val, y_val) in enumerate(zip(x.flatten(), y.flatten())):
            c = cm[int(x_val), int(y_val)]
            ax.text(y_val, x_val, format(c, fmt), va='center', ha='center')

    if save_path is not None:
        plt.savefig(save_path)

class_dictionary = {3: 'dog_bark', 2: 'children_playing', 1: 'car_horn', 0: 'air_conditioner', 9: 'street_music', 6: 'gun_shot', 8: 'siren', 5: 'engine_idling', 7: 'jackhammer', 4: 'drilling'}
classes = [class_dictionary[key] for key in sorted(class_dictionary.keys())]

plot_confusion_matrix(matrix, classes)
